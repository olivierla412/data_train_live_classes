# %% [markdown]
# ![](1.png)

# %% [markdown]
# ![](2.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import seaborn as sns
from sklearn.model_selection import train_test_split
warnings.filterwarnings('ignore')

# %%
### fetching and loading the dataset

url = "https://raw.githubusercontent.com/dsrscientist/DSData/master/Telecom_customer_churn.csv"
data = pd.read_csv(url)

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ### Using head() method help us to see the first 5 records of our dataset.

# %%
data.shape
# Out:
# (7043, 21)

# %% [markdown]
# ### From the Shape method we can see the shape of our dataset which has 7043 records(rows) and 21 attributes (columns)

# %%
pd.options.display.max_columns = None

# %%
data.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
#
#   PaperlessBilling     PaymentMethod  MonthlyCharges TotalCharges Churn
# 0              Yes  Electronic check           29.85        29.85    No
# 1               No      Mailed check           56.95       1889.5    No

# %%
print("--"*40)
print("--"*40)
# Out:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------

# %%
data.Churn.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# ## __From the above problem statement we are asked to build a model which can predict customers church, whether the customer will stay or not. Since the outcome "Churn " which is our target variable has categorical data we can assume that it is a classification problem. Also using unique() method on the target variable we can see clearly that it has only two classes, so we can say that is a binary classification problem.__

# %%
print("--"*40)
print("--"*40)
# Out:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------

# %%
## Let's verify is there any duplicate records and remove them.
data.duplicated().any()
# Out:
# False

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### From the above verification we can confirmed that there is not duplicated values in our dataset.

# %%
## let's drop the customerID column because it is nominal data.
data.drop('customerID',axis=1,inplace=True)

# %%
data.shape
# Out:
# (7043, 20)

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# ### Using describe() we can see that 3 columns have numerical data and we see the statistical of the data in each columns.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %% [markdown]
# ### From the info() method we can see some details about our dataset, like the "data type" (dtypes), the columns indexes and the "Non-Null Count". we can see that our dataset have no missing values since non-null count of all the columns are same and equal to 7043.

# %%
data.isna().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ### From the above verification we can see that our dataset have no missing values. great.

# %%
## This will help us to see how is the shape of the data in each column.

for column in data.columns:
    print(data[column].value_counts())
    print('**'*20)
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64
# ****************************************
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64
# ****************************************
# No     3641
# Yes    3402
# Name: Partner, dtype: int64
# ****************************************
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64
# ****************************************
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64
# ****************************************
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64
# ****************************************
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64
# ****************************************
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64
# ...

# %% [markdown]
# ### From the above verification I can say that all the columns are important..

# %% [markdown]
# ## Let's do some Encoding...

# %%
## converting gender column data into number

data['gender'] = data['gender'].replace({'Male':1,'Female':0})

# %%
## converting Partner column data into number

data['Partner'] = data['Partner'].replace({'Yes':1,'No':0})

# %%
## converting Dependents column data into number

data['Dependents'] = data['Dependents'].replace({'Yes':0,'No':1})

# %%
## converting PhoneService column  data into number

data['PhoneService'] = data['PhoneService'].replace({'Yes':1,'No':0})

# %%
## converting MultipleLines column data into number

data['MultipleLines'] = data['MultipleLines'].replace({'Yes':2,'No':1,'No phone service':0})

# %%
## converting InternetService column data into number

data['InternetService'] = data['InternetService'].replace({'Fiber optic':2,'DSL':1,'No':0})

# %%
## converting OnlineSecurity column data into number

data['OnlineSecurity'] = data['OnlineSecurity'].replace({'Yes':2,'No':1,'No internet service':0})

# %%
## converting OnlineBackup column data into number

data['OnlineBackup'] = data['OnlineBackup'].replace({'Yes':2,'No':1,'No internet service':0})

# %%
## converting DeviceProtection column data into number

data['DeviceProtection'] = data['DeviceProtection'].replace({'Yes':2,'No':1,'No internet service':0})

# %%
## converting column TechSupport data into number

data['TechSupport'] = data['TechSupport'].replace({'Yes':2,'No':1,'No internet service':0})

# %%
## converting column StreamingTV data into number

data['StreamingTV'] = data['StreamingTV'].replace({'Yes':2,'No':1,'No internet service':0})

# %%
## converting column StreamingMovies data into number

data['StreamingMovies'] = data['StreamingMovies'].replace({'Yes':2,'No':1,'No internet service':0})

# %%
## converting column Contract data into number

data['Contract'] = data['Contract'].replace({'Two year':2,'One year':1,'Month-to-month':0})

# %%
## converting PaperlessBilling column  data into number

data['PaperlessBilling'] = data['PaperlessBilling'].replace({'Yes':1,'No':0})

# %%
## converting column PaymentMethoddata into number

data['PaymentMethod'] = data['PaymentMethod'].replace({'Bank transfer (automatic)':3,'Credit card (automatic)':2,'Mailed check':1,'Electronic check':0}
                                                    )

# %%
## converting Churn column data into number

data['Churn'] = data['Churn'].replace({'Yes':1,'No':0})

# %%
data
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           1       1             0
# 1          1              0        0           1      34             1
# 2          1              0        0           1       2             1
# 3          1              0        0           1      45             0
# 4          0              0        0           1       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           0      24             1
# 7039       0              0        1           0      72             1
# 7040       0              0        1           0      11             0
# 7041       1              1        1           1       4             1
# 7042       1              0        0           1      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
data.TotalCharges
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: TotalCharges, Length: 7043, dtype: object

# %% [markdown]
# ### we can see that the "TotalCharges" column have numerical data but is still have object type so let's convert  into dtypes ("float"). but let's replace the empty values by the mode() since we cannot used mean()

# %%
## so we will the those empty values by the mode .


data['TotalCharges'].mode()
# Out:
# 0
# 1    20.2
# dtype: object

# %%
data['TotalCharges'] = data['TotalCharges'].replace({' ':20.2})

# %%
# Now let's convert the type into float

data['TotalCharges'] = data['TotalCharges'].astype(float)

# %%
data['TotalCharges']
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   int64
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   int64
#  3   Dependents        7043 non-null   int64
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   int64
#  6   MultipleLines     7043 non-null   int64
#  7   InternetService   7043 non-null   int64
#  8   OnlineSecurity    7043 non-null   int64
#  9   OnlineBackup      7043 non-null   int64
#  10  DeviceProtection  7043 non-null   int64
#  11  TechSupport       7043 non-null   int64
#  12  StreamingTV       7043 non-null   int64
#  13  StreamingMovies   7043 non-null   int64
#  14  Contract          7043 non-null   int64
#  15  PaperlessBilling  7043 non-null   int64
# ...

# %% [markdown]
# ### From the info() we can see that our data doesnot have anymore __Object Dtype__  and it has only __int64 and float64 Dtype__.

# %%
data.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           1       1             0
# 1       1              0        0           1      34             1
# 2       1              0        0           1       2             1
# 3       1              0        0           1      45             0
# 4       0              0        0           1       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              0                1               1             2
# 1              1                1               2             1
# 2              1                1               2             2
# 3              0                1               2             1
# 4              1                2               1             1
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 1            1            1                1         0
# ...

# %%
data.describe()
# Out:
#             gender  SeniorCitizen      Partner   Dependents       tenure  \
# count  7043.000000    7043.000000  7043.000000  7043.000000  7043.000000
# mean      0.504756       0.162147     0.483033     0.700412    32.371149
# std       0.500013       0.368612     0.499748     0.458110    24.559481
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       1.000000       0.000000     0.000000     1.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# count   7043.000000    7043.000000      7043.000000     7043.000000
# mean       0.903166       1.325004         1.222916        1.069999
# std        0.295752       0.642730         0.778877        0.706051
# ...

# %% [markdown]
# ## From the describe() method we can see ,how the data is distributed in each column.we can see also the count, the mean,the standar deviation of each column and also the the minimum and the maximum and the quantitles of each column. for the numerical columns.

# %%
print("**"*50)
print("**"*50)
# Out:
# ****************************************************************************************************
# ****************************************************************************************************

# %% [markdown]
# ### __Now let's save the cleaned data before further process.__

# %%
data.to_csv('cleaned_data.csv',index=False)

# %%
## Let's load the the cleaned data
new_data = pd.read_csv('cleaned_data.csv')

# %%
new_data.head(2)
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           1       1             0
# 1       1              0        0           1      34             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              0                1               1             2
# 1              1                1               2             1
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 1            1            1                1         0
# 1                 2            1            1                1         1
#
#    PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn
# 0                 1              0           29.85         29.85      0
# 1                 0              1           56.95       1889.50      0

# %%
new_data.plot(kind='density',subplots=True,
          layout=(6,11),sharex=False,
          legend=False,fontsize='2',
          figsize =(18,12))
plt.show()

# %% [markdown]
# ### From this density graph we can see that most the columns in the dataset have not normal distribution format shape.

# %%
# plot a  distplot check the distribution

plt.figure(figsize=(18,25))
plotnumber = 1

for column in new_data:
    if plotnumber <= 20:
        ax = plt.subplot(5,4,plotnumber)
        sns.distplot(new_data[column],bins=30,color='purple')
        plt.xlabel(column,fontsize = 15,color='red')
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### From distplot graph we can see that our data is not distributed normally for most the columns since we can see a lot of skewness. So let's if we can remove them...

# %%
plt.figure(figsize=(20,25))
plotnumber = 1

for column in new_data:
    if plotnumber <= 20:
        ax = plt.subplot(5,4,plotnumber)
        sns.boxplot(y= new_data[column],color='green',orient='h')
        plt.xlabel(column,fontsize = 20,color='red')
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### From the above boxplot graph we can say that there no outliers in our dataset and that is great.

# %% [markdown]
# ### __Skewness removal__

# %%
## importing the libraries
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer(method='yeo-johnson')

# %%
## we will remove skewness form the features columns

features = new_data.drop('Churn',axis=1)

# %%
X_power=pt.fit_transform(features)

# %%
X_power
# Out:
# array([[-1.00955867, -0.43991649,  1.03453023, ..., -1.24171834,
#         -1.1585412 , -1.80333283],
#        [ 0.99053183, -0.43991649, -0.96662231, ..., -0.08926802,
#         -0.23949171,  0.25670407],
#        [ 0.99053183, -0.43991649, -0.96662231, ..., -0.08926802,
#         -0.34266505, -1.38024567],
#        ...,
#        [-1.00955867, -0.43991649,  1.03453023, ..., -1.24171834,
#         -1.16724064, -0.8536474 ],
#        [ 0.99053183,  2.27315869,  1.03453023, ..., -0.08926802,
#          0.33431207, -0.91660038],
#        [ 0.99053183, -0.43991649, -0.96662231, ...,  1.30928099,
#          1.33886338,  1.48330252]])

# %%
## Now let's convert the result into a DataFrame

df=pd.DataFrame(X_power,columns=features.columns)

# %%
df
# Out:
#         gender  SeniorCitizen   Partner  Dependents    tenure  PhoneService  \
# 0    -1.009559      -0.439916  1.034530    0.654012 -1.644343     -3.054010
# 1     0.990532      -0.439916 -0.966622    0.654012  0.297205      0.327438
# 2     0.990532      -0.439916 -0.966622    0.654012 -1.495444      0.327438
# 3     0.990532      -0.439916 -0.966622    0.654012  0.646327     -3.054010
# 4    -1.009559      -0.439916 -0.966622    0.654012 -1.495444      0.327438
# ...        ...            ...       ...         ...       ...           ...
# 7038  0.990532      -0.439916  1.034530   -1.529024 -0.078084      0.327438
# 7039 -1.009559      -0.439916  1.034530   -1.529024  1.342198      0.327438
# 7040 -1.009559      -0.439916  1.034530   -1.529024 -0.725121     -3.054010
# 7041  0.990532       2.273159  1.034530    0.654012 -1.265130      0.327438
# 7042  0.990532      -0.439916 -0.966622    0.654012  1.201896      0.327438
#
# ...

# %%
# let's check again the distribution in the feature columns.

plt.figure(figsize=(18,25))
plotnumber = 1

for column in df:
    if plotnumber <= 19:
        ax = plt.subplot(5,4,plotnumber)
        sns.distplot(df[column],bins=30,color='green')
        plt.xlabel(column,fontsize = 15,color='red')
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### From here can see that our data look better than before, and it has less kewness.

# %%
## let's check the classes in our target columns
new_data['Churn'].hist(grid=True,color='green')
plt.title('Churn(No ) VS Churn(Yes)')
plt.show()

# %% [markdown]
# ### From this histogram we can see that the classes are imbalance and 'Churn(No ) is majority and 'Churn(Yes ) is the minority. So let's handling class imbalance using oversampling the minority class.

# %%
## importang the libraries
from imblearn.over_sampling import SMOTE

SM = SMOTE()

# %%
y = new_data['Churn']

# %%
x_over , y_over = SM.fit_resample(df, y)

# %%
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        1
#         ..
# 10343    1
# 10344    1
# 10345    1
# 10346    1
# 10347    1
# Name: Churn, Length: 10348, dtype: int64

# %%
## let's check the classes in our target columns
y_over.hist(grid=True,color='orange')
plt.title('Churn(No ) VS Churn(Yes)')
plt.show()

# %% [markdown]
# ### Now we can see that our both classes of the label are balanced so we can build our model.

# %% [markdown]
# ## __Before fit our data to the models ,let's see by visualize the relationship bw the features and the label usig stripplot() method.__

# %%
plt.figure(figsize=(20,25), facecolor='white')
plot_no = 1

for column in x_over:
    if plot_no <= 19:
        ax = plt.subplot(5,4,plot_no)
        sns.stripplot(y_over, x_over[column])
    plot_no+=1
plt.tight_layout()

# %% [markdown]
# ### From the above graphs, we can say that all the features are important and they have a  relationship with our label Churn (target column).

# %% [markdown]
# ### __Now let's build the models__

# %%
### Importing the libraries

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [markdown]
# ### First with LogisticRegression and find the random state.

# %%
max_accu = 0
max_RS = 0
for i in range(1,400):
    x_train, x_test, y_train,y_test = train_test_split(x_over,y_over,
                                                    test_size=30,
                                                    random_state=i)
    LR = LogisticRegression()
    LR.fit(x_train, y_train)
    predrf = LR.predict(x_test)
    acc = accuracy_score(y_test, predrf)
    if acc > max_accu:
        max_accu = acc
        max_RS = i
print('Best accuracy is :',max_accu, 'on Random_state',max_RS)
# Out:
# Best accuracy is : 0.9666666666666667 on Random_state 3

# %% [markdown]
# ### __This code above help us to find the best random_state = 3 and accuracy = 96%__

# %%
## let's build gain the model using the ramdom_state=3

x_train, x_test, y_train,y_test = train_test_split(x_over,y_over,
                                                    test_size=30,
                                                    random_state=3)
lr_model = LogisticRegression()
lr_model.fit(x_train, y_train)
y_predlr = lr_model.predict(x_test)
print("The Accuracy is :",accuracy_score(y_test, y_predlr))
print('--'*20)
print(confusion_matrix(y_test,y_predlr))
print(classification_report(y_test,y_predlr))
# Out:
# The Accuracy is : 0.9666666666666667
# ----------------------------------------
# [[13  1]
#  [ 0 16]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96        14
#            1       0.94      1.00      0.97        16
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ### __We built the first model using LogisticRegression Algorithum and the accuracy is : 97%__

# %% [markdown]
# ## Let's build a more models select the best one.

# %%
## import the libraries

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC # Suport Vector Machine model
from sklearn.ensemble import GradientBoostingClassifier

# %%
### DecisionTreeClassifier model.

dt = DecisionTreeClassifier(random_state=3)
dt.fit(x_train, y_train)
pred_dt = dt.predict(x_test)
print("The Accuracy is :",accuracy_score(y_test, pred_dt))
print('--'*20)
print(confusion_matrix(y_test, pred_dt))
print(classification_report(y_test,pred_dt))
# Out:
# The Accuracy is : 0.9
# ----------------------------------------
# [[12  2]
#  [ 1 15]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89        14
#            1       0.88      0.94      0.91        16
#
#     accuracy                           0.90        30
#    macro avg       0.90      0.90      0.90        30
# weighted avg       0.90      0.90      0.90        30

# %% [markdown]
# ### __DecisionTreeClassifier Accuracy is : 90%__

# %%
print('**'*30)
print('**'*30)
# Out:
# ************************************************************
# ************************************************************

# %%
## RandomForestClassifier

rf = RandomForestClassifier(3)
rf.fit(x_train, y_train)
pred_rf = rf.predict(x_test)

print("The Accuracy is :",accuracy_score(y_test, pred_rf))
print('--'*20)
print(confusion_matrix(y_test, pred_rf))
print(classification_report(y_test,pred_rf))
# Out:
# The Accuracy is : 0.8333333333333334
# ----------------------------------------
# [[10  4]
#  [ 1 15]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.71      0.80        14
#            1       0.79      0.94      0.86        16
#
#     accuracy                           0.83        30
#    macro avg       0.85      0.83      0.83        30
# weighted avg       0.85      0.83      0.83        30

# %% [markdown]
# ### __RandomForestClassifier Accuracy is : 83%__

# %%
print('**'*30)
print('**'*30)
# Out:
# ************************************************************
# ************************************************************

# %%
# Suport Vector Machine model( SVC )

svc = SVC(random_state=3)

svc.fit(x_train, y_train)

pred_svc = svc.predict(x_test)

print("The Accuracy is :",accuracy_score(y_test, pred_svc))
print('--'*20)
print(confusion_matrix(y_test,pred_svc))
print(classification_report(y_test,pred_svc))
# Out:
# The Accuracy is : 0.9666666666666667
# ----------------------------------------
# [[13  1]
#  [ 0 16]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96        14
#            1       0.94      1.00      0.97        16
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ### __Suport Vector Machine model gives Accuracy = 97%__

# %%
print('**'*30)
print('**'*30)
# Out:
# ************************************************************
# ************************************************************

# %%
### GrandientBoostingClassifier model

gbdt_clf = GradientBoostingClassifier(random_state=3)
gbdt_clf.fit(x_train,y_train)
pred_gb = gbdt_clf.predict(x_test)
print("The Accuracy is :",accuracy_score(y_test, pred_gb))
print('--'*20)
print(confusion_matrix(y_test,pred_gb))
print(classification_report(y_test,pred_gb))
# Out:
# The Accuracy is : 0.9
# ----------------------------------------
# [[12  2]
#  [ 1 15]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89        14
#            1       0.88      0.94      0.91        16
#
#     accuracy                           0.90        30
#    macro avg       0.90      0.90      0.90        30
# weighted avg       0.90      0.90      0.90        30

# %% [markdown]
# ### __GrandientBoostingClassifier model gives accuracy = 90%__

# %%
print('**'*30)
# Out:
# ************************************************************

# %% [markdown]
# ## __Let's go for cross validation score and see if there is overfitting or not and wich model performe better among them.__

# %%
### importing the library

from sklearn.model_selection import cross_val_score

# %%
## first  model lr_model

scr = cross_val_score(lr_model,x_over,y_over,cv=7)
print('Cross Validation Score of LogisticRegression model:',scr.mean())
print('--'*35)
# Out:
# Cross Validation Score of LogisticRegression model: 0.7794762998755566
# ----------------------------------------------------------------------

# %%
## second  model dt

scr = cross_val_score(dt,x_over,y_over,cv=7)
print('Cross Validation Score of DecisionTreeClassifier model:',scr.mean())
print('--'*35)
# Out:
# Cross Validation Score of DecisionTreeClassifier model: 0.7879938312873561
# ----------------------------------------------------------------------

# %%
## Third model rf

scr = cross_val_score(rf,x_over,y_over,cv=7)
print('Cross Validation Score of  RandomForestClassifier model:',scr.mean())
print('--'*35)
# Out:
# Cross Validation Score of  RandomForestClassifier model: 0.8107998740534895
# ----------------------------------------------------------------------

# %%
## Fourth model svc

scr = cross_val_score(svc,x_over,y_over,cv=7)

print('Cross Validation Score of Suport Vector Machine model:',scr.mean())
print('--'*35)
# Out:
# Cross Validation Score of Suport Vector Machine model: 0.8005460688311533
# ----------------------------------------------------------------------

# %%
## Fith model GradientBoostingClassifier

scr = cross_val_score(gbdt_clf,x_over,y_over,cv=7)

print('Cross Validation Score of GradientBoostingClassifier model:',scr.mean())
print('--'*35)
# Out:
# Cross Validation Score of GradientBoostingClassifier model: 0.8375704348278437
# ----------------------------------------------------------------------

# %%
print('\nLogisticRegression model diff is:',97 -77)
print('--'*35)
print('\nDecisionTreeClassifier model diff is:',90 -78)
print('--'*35)
print('\nRandomForestClassifier  model diff is:',83 -81)
print('--'*35)
print('\nSuport Vector Machine model diff is:',97 -80)
print('--'*35)
print('\nGradientBoostingClassifier model diff is:',90 -83)
# Out:
# LogisticRegression model diff is: 20
# ----------------------------------------------------------------------
#
# DecisionTreeClassifier model diff is: 12
# ----------------------------------------------------------------------
#
# RandomForestClassifier  model diff is: 2
# ----------------------------------------------------------------------
#
# Suport Vector Machine model diff is: 17
# ----------------------------------------------------------------------
#
# GradientBoostingClassifier model diff is: 7

# %% [markdown]
# ## __The minimum difference in accuracy and cross validation score is for RandomForestClassifier model, So it is our best model.__

# %% [markdown]
# ### __We are selected the RandomForestClassifier model with accuracy: 83% as our best model.__

# %% [markdown]
# ### __Let's try if we can improve the performance of our model using Hyperparameter Tuning__

# %%
### importing the libraries

from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
# we are passing the different values for both paramters

grid_param = {
    'criterion':['gini','entropy'],
    'max_features': ['sqrt','log2'],
    'max_depth':range(2,10,3),
    'min_samples_leaf':range(1,10,2),
    'min_samples_split':range(2,10,2)
}

# %%
grid_search = GridSearchCV(estimator=rf,
                         param_grid=grid_param,
                         cv=7,
                         n_jobs=-1)

# %%
## again train the model

grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=7, estimator=RandomForestClassifier(n_estimators=3), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 10, 3),
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': range(1, 10, 2),
#                          'min_samples_split': range(2, 10, 2)})

# %%
# best parameters

best_parameters = grid_search.best_params_
print(best_parameters)
# Out:
# {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 6}

# %%
## so let's build again the decisionTreeClassifier

rf_model = RandomForestClassifier(criterion='entropy',
                            max_features ='sqrt',
                            max_depth=8,
                            min_samples_leaf=3,
                            min_samples_split=6,
                            random_state=3)

# %%
## let's fit gain the model with the data

rf_model.fit(x_train,y_train)
pred_drf = rf_model.predict(x_test)
rf_model_report = pd.DataFrame(classification_report(
    y_test,pred_rf,output_dict=True))


print("\n=============Test Result==============")

print(f"Accuracy Score:{accuracy_score(y_test,pred_drf)*100:.2f}%")
print("_____________________________________________")
print(f"CLASSIFICATION REPORT:\n{rf_model_report}")
print("_____________________________________________")
print(f"Confusion Matrix:\n{confusion_matrix(y_test,pred_drf)}\n")
# Out:
# =============Test Result==============
# Accuracy Score:93.33%
# _____________________________________________
# CLASSIFICATION REPORT:
#                    0          1  accuracy  macro avg  weighted avg
# precision   0.909091   0.789474  0.833333   0.849282      0.845295
# recall      0.714286   0.937500  0.833333   0.825893      0.833333
# f1-score    0.800000   0.857143  0.833333   0.828571      0.830476
# support    14.000000  16.000000  0.833333  30.000000     30.000000
# _____________________________________________
# Confusion Matrix:
# [[12  2]
#  [ 0 16]]

# %% [markdown]
# ### After Hyper paramter Turning we are able to improve our model accury from 83% Accuracy to 93% Accuracy great, So let's save model as it is.

# %% [markdown]
# ### __Conclusion: RandomForestClassifier (rf_model) is our best model with 93% accuracy.__

# %% [markdown]
# ### __Let's save the model.__

# %%
## import the librarie
import joblib

# %%
joblib.dump(rf_model,'Customer_Churn_Prediction_Model.pkl')
# Out:
# ['Customer_Churn_Prediction_Model.pkl']

# %%
print('**'*30)
# Out:
# ************************************************************

# %% [markdown]
# # __END OF THE PROJECT Thank YOU !!!__
