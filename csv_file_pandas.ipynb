# %%
import pandas as pd
import numpy as np

# %%
info = 'sql_data.csv'

# %%
data = pd.read_csv(info)

# %%
data
# Out:
#    gender  student_id  marks
# 0    male         100     50
# 1  female         200     67
# 2  female         201     70
# 3    male         202     65
# 4  female         203     77
# 5  female         204     66

# %%
data.sample(n =3)

## any time you run , the sample values will change
# Out:
#    gender  student_id  marks
# 1  female         200     67
# 0    male         100     50
# 2  female         201     70

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (6, 3)

# %%
## differente location

infos = '/Users/olivierla412/projects/data_camp/service_data_set.csv'

# %%
data = pd.read_csv(infos)

# %%
data.sample(10)
# Out:
#     Unique Key            Created Date             Closed Date Agency  \
# 42    26590480  10/31/2013 12:15:06 AM  10/31/2013 03:00:20 AM   NYPD
# 10    26595176  10/31/2013 01:25:12 AM                     NaN   NYPD
# 37    26589606  10/31/2013 12:20:44 AM  10/31/2013 02:10:24 AM   NYPD
# 41    26593296  10/31/2013 12:16:25 AM                     NaN  DOHMH
# 23    26592304  10/31/2013 12:38:00 AM                     NaN   NYPD
# 27    26591379  10/31/2013 12:32:44 AM                     NaN  DOHMH
# 44    26592898  10/31/2013 12:12:08 AM  10/31/2013 01:13:45 AM   NYPD
# 38    26592083  10/31/2013 12:20:00 AM                     NaN    DOT
# 33    26593872  10/31/2013 12:29:47 AM  10/31/2013 12:38:29 AM   NYPD
# 28    26594085  10/31/2013 12:32:08 AM                     NaN   NYPD
#
#                                 Agency Name            Complaint Type  \
# 42          New York City Police Department        Noise - Commercial
# ...

# %% [markdown]
# # Exporting data

# %%
data.to_csv('service_data_set.csv')

# %% [markdown]
# ## to retrived specific columns

# %%
data1= data[['Created Date','Closed Date']]

# %%
data.dtypes
# Out:
# Unique Key                 int64
# Created Date              object
# Closed Date               object
# Agency                    object
# Agency Name               object
# Complaint Type            object
# Descriptor                object
# Location Type             object
# Incident Zip             float64
# Incident Address          object
# Street Name               object
# Cross Street 1            object
# Cross Street 2            object
# Intersection Street 1     object
# Intersection Street 2     object
# Address Type              object
# City                      object
# dtype: object

# %% [markdown]
# ## options.display.max_rows
# #### Restriction on the number of rows should display any time you run your DataFrame

# %%
pd.options.display.max_rows = 8

# %%
data
# Out:
#     Unique Key            Created Date             Closed Date Agency  \
# 0     26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1     26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2     26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3     26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# ..         ...                     ...                     ...    ...
# 45    26590446  10/31/2013 12:11:58 AM  10/31/2013 01:54:38 AM   NYPD
# 46    26595546  10/31/2013 12:09:07 AM  10/31/2013 12:53:12 AM   NYPD
# 47    26595944  10/31/2013 12:08:47 AM                     NaN    TLC
# 48    26595084  10/31/2013 12:07:45 AM  10/31/2013 01:43:11 AM   NYPD
#
#                         Agency Name           Complaint Type  \
# 0   New York City Police Department  Noise - Street/Sidewalk
# 1   New York City Police Department          Illegal Parking
# 2   New York City Police Department       Noise - Commercial
# ...
